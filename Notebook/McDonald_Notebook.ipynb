# %% [markdown]
# ## Import neccessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import the dataset and Loaded the dataset - Mcdonald dataset

# %%
data= pd.read_csv("C:\\Users\\admin\\Downloads\\Nutrical Dataset (2).csv")
data
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# ### Initial Glance of the dataset records by head() & tail()

# %%
#view of first 5 rows

data.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#view of last 5 rows

data.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %% [markdown]
# ## Information about the dataset

# %%
data.shape
# Out:
# (260, 24)

# %% [markdown]
# ### RESULT : It contains 260 rows and 24 columns in the given dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#count of different data type

data.dtypes.value_counts()
# Out:
# int64      18
# object      3
# float64     3
# Name: count, dtype: int64

# %% [markdown]
# ### It shows we have 18 integers, 3 floats and 3 objects (Categorial) datatype for 24 columns.

# %% [markdown]
# ### Q: Now we will check, wheather our dataset contains the missing values or not.

# %%
data.isna().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# ### conclusion : From the above result, we can conclude that there's no null value or missing values are present                                  in dataset.

# %% [markdown]
# ### Observation: 1) All columns data types are correct, except Serving Size column because it supposed to be                                           int64, not object data type.                                                                                                                                                   2) Most of the nutrients have a column of percentage daily need but Sugars, Protein, and Calorie                                     does not have percentage daily needs column so we are going to add Sugars, Protein, and                                           Calories column in percentage daily needs.

# %% [markdown]
# ### Action : If we read how all data write in Serving Size, there are several weight/volume units to describe the                               menus. That is Ounce (oz), Fluid Ounce (fl oz), Gram (g) and Millilitre (ml). Most of the data use an                               ounce or gram unit for food and fluid oz for a drink, but some data like 1% Low Fat Milk Jug and Fat-                         Free Chocolate Milk Jug items use millilitre unit. So we're going to transform all unit to gram unit, and                       for data who didn't provide mass unit (like a fluid ounce or millilitre), we're going to use the density of                       milk (Only milk item who didn't have mass unit) for millilitre and than for fluid once we're going to use                       the density of pure water.

# %%
### Code :
serving_size_conv = []
for i in data['Serving Size']:
    if '(' in i and 'g)' in i:
        serving_size_conv.append(float(i[i.find('(')+1:-3])) 
    elif 'fl oz' in i:
        serving_size_conv.append(float(i[0:i.find(' ')])*29.5735) ## assume 1 fl oz = 29.5735 g
    elif '(' and 'ml)':
        serving_size_conv.append(float(i[i.find('(')+1:-4])*1.04) ## assume 1 ml = 1.04g

data['Serving Size']= pd.DataFrame(serving_size_conv).astype('float')

# %%
# we are adding unit i.e gm to serving size column 

data.rename(columns={ "Serving Size": "serving Size (gm)"}, inplace=True)
data
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# ### After normalized Serving Size column, let's add Sugars, Protein, and Calories column in percentage daily                  needs unit.
#
# ### As a guide: 1) An average man needs 2,500 kcal(calories) a day.                                                                                                             2)An average man needs 30gm sugar a day.                                                                                                                           3)An average man needs 50gm protein a day

# %%
data['Calories (% Daily Value)'] =data['Calories']*100/2500 

data['Sugars (% Daily Value)'] = data['Sugars']*100/30

data['Protein (% Daily Value)'] = data['Protein']*100/50

data.head()
# Out:
#     Category                              Item  serving Size (gm)  Calories  \
# 0  Breakfast                      Egg McMuffin              136.0       300
# 1  Breakfast                 Egg White Delight              135.0       250
# 2  Breakfast                  Sausage McMuffin              111.0       370
# 3  Breakfast         Sausage McMuffin with Egg              161.0       450
# 4  Breakfast  Sausage McMuffin with Egg Whites              161.0       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
# Note : Sugars (% Daily Value) column has decimal upto 6 digits, so we will round this upto 2 digit

data["Sugars (% Daily Value)"] = data["Sugars (% Daily Value)"].round(2)

data
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# ### Conclusion: After the dataset has been checked and cleaned. Now the dataset is ready to use and we can start                              dive into our dataset for Data Exploration.
#
# ### --> Let's describe our data first

# %%
data.describe()
# Out:
#        serving Size (gm)     Calories  Calories from Fat   Total Fat  \
# count         260.000000   260.000000         260.000000  260.000000
# mean          376.234264   368.269231         127.096154   14.165385
# std           208.960847   240.269886         127.875914   14.205998
# min            29.000000     0.000000           0.000000    0.000000
# 25%           199.250000   210.000000          20.000000    2.375000
# 50%           354.882000   340.000000         100.000000   11.000000
# 75%           473.176000   500.000000         200.000000   22.250000
# max           946.352000  1880.000000        1060.000000  118.000000
#
#        Total Fat (% Daily Value)  Saturated Fat  \
# count                 260.000000     260.000000
# mean                   21.815385       6.007692
# std                    21.885199       5.321873
# min                     0.000000       0.000000
# 25%                     3.750000       1.000000
# 50%                    17.000000       5.000000
# ...

# %% [markdown]
# ### conclusion: From the above we can easily find out count, mean , standard deviation, min, 25%, 50%, 75%, and                                max of all columns which has numerical value and it is very handy.

# %% [markdown]
# ### question: Now we will find out Count, Min, Max, Sum, and Mean of calories column by category wise.

# %%
by_category = pd.DataFrame({'Category':data['Category'].value_counts().index.tolist(),
                            'Count':data['Category'].value_counts().tolist(),
                             'Calories (min)':data[['Category','Calories']].groupby('Category').min()['Calories'],
                             'Calories (max)':data[['Category','Calories']].groupby('Category').max()['Calories'],
                            'Calories (Sum)':data[['Category','Calories']].groupby('Category').sum()['Calories'],
                            'Calories (Mean)':data[['Category','Calories']].groupby('Category').mean()['Calories']})
by_category.reset_index(drop = True)
# Out:
#              Category  Count  Calories (min)  Calories (max)  Calories (Sum)  \
# 0        Coffee & Tea     95             240             750            7410
# 1           Breakfast     42               0             280            3070
# 2  Smoothies & Shakes     28             150            1150           22120
# 3      Chicken & Fish     27             190            1880           14930
# 4           Beverages     27               0             760           26970
# 5         Beef & Pork     15              45             340            1555
# 6      Snacks & Sides     13             140             450            1620
# 7            Desserts      7             210             930           14880
# 8              Salads      6              15             510            3195
#
#    Calories (Mean)
# 0       494.000000
# 1       113.703704
# 2       526.666667
# 3       552.962963
# 4       283.894737
# 5       222.142857
# 6       270.000000
# 7       531.428571
# ...

# %% [markdown]
# ### Result: From the above dataframe, we can easily find out the counts, Min, Max and Mean of calories by                                   catogory wise.
#
# ### 1) Average maximum calories and Max. calories per item which came from Chicken & Fish category.
#
# ### 2) Min. calories per item come from "Breakfast" and "Beverages" category.

# %% [markdown]
# ### Now we will visualize "by_category" dataframe, to get which category has the maximum no. of items and max.        avg. max. colories

# %%
fig,(ax1,ax2) = plt.subplots(1,2)
fig.set_size_inches(15.5, 7.5)
ax1.set_title("Total Items in Each Category")
ax1.pie(by_category['Count'],labels =by_category['Category'],autopct = '%1.1f%%')

ax2.set_title("Avg. total Calories in Each Category")
ax2.pie(by_category['Calories (Mean)'],labels =by_category['Category'],autopct = '%1.1f%%')

fig.suptitle('Calories by Category',fontsize = 20)
fig.legend(by_category['Category'],ncol=4,loc=8)

# %% [markdown]
# ### conclusion: 1) "Coffee & Tea" has max. no. of items which is 36.5% of total no. of items but it stands                                                    4th(fourth) in avg. clories per item i.e 15.2%                                                                                                                     2)  "Chicken & Fish" has max. Average colorie per item despite of it has fourth most (4th)                                                   total no. of items i.e 10.4%

# %% [markdown]
# ## Let's see how the correlation of calories and nutrients with the help of Heatmap plot:

# %%
nutrition = ['serving Size (gm)',
 'Calories',
 'Calories from Fat',
 'Total Fat',
 'Saturated Fat',
 'Trans Fat',
 'Cholesterol',
 'Sodium',
 'Carbohydrates',
 'Dietary Fiber',
 'Sugars',
 'Protein',
 'Vitamin A (% Daily Value)',
 'Vitamin C (% Daily Value)',
 'Calcium (% Daily Value)',
 'Iron (% Daily Value)']

corr = data[nutrition].corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
fig = plt.figure(figsize = (13,13))

ax = sns.heatmap(corr,
                 mask = mask,
                 square =True,
                 cmap="vlag",
                 annot=True,
                 fmt="1.2f"
                )
ax.set_title("Nutrition Correlation",fontsize = 20);

# %% [markdown]
# ### CONCLUSION: 1) From the above figure, we can conclude that Calories has the highest correlation with Fat.                                           It means more fat in a menu implies that more calories are present in the menu. followed by                                         Protein in second place (0.79) and Carbohydrates in third place (0.78).                                                                                                                                                                                                                                                                             2) Besides the correlation with the calories, there's a high correlation score in another feature,                                       for example the correlation between Sodium and Iron (0.87), and Sodium between                                                         Protein is (0.87).

# %% [markdown]
# ### question: Identify menu items with highest and lowest calorie.

# %%
item_calorie= data[["Category","Item","Calories"]].sort_values("Calories",ascending=False)

item_calorie
# Out:
#            Category                                               Item  \
# 82   Chicken & Fish                       Chicken McNuggets (40 piece)
# 32        Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31        Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34        Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33        Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# ..              ...                                                ...
# 117       Beverages                                  Diet Coke (Child)
# 116       Beverages                                  Diet Coke (Large)
# 115       Beverages                                 Diet Coke (Medium)
# 114       Beverages                                  Diet Coke (Small)
# 146    Coffee & Tea                                    Coffee (Medium)
#
#      Calories
# 82       1880
# 32       1150
# 31       1090
# 34       1050
# 33        990
# ..        ...
# ...

# %%
#item having minimum calorie 
min_calories = item_calorie["Calories"].min()
min_item_cal = item_calorie[item_calorie["Calories"] == min_calories]
min_item_cal
# Out:
#          Category                     Item  Calories
# 145  Coffee & Tea           Coffee (Small)         0
# 140  Coffee & Tea         Iced Tea (Child)         0
# 139  Coffee & Tea         Iced Tea (Large)         0
# 138  Coffee & Tea        Iced Tea (Medium)         0
# 137  Coffee & Tea         Iced Tea (Small)         0
# 136     Beverages      Dasani Water Bottle         0
# 123     Beverages  Diet Dr Pepper (Medium)         0
# 125     Beverages   Diet Dr Pepper (Child)         0
# 124     Beverages   Diet Dr Pepper (Large)         0
# 122     Beverages   Diet Dr Pepper (Small)         0
# 147  Coffee & Tea           Coffee (Large)         0
# 117     Beverages        Diet Coke (Child)         0
# 116     Beverages        Diet Coke (Large)         0
# 115     Beverages       Diet Coke (Medium)         0
# 114     Beverages        Diet Coke (Small)         0
# 146  Coffee & Tea          Coffee (Medium)         0

# %% [markdown]
# ### conclusion:
# And there are many items which having Minimum calorie counts i.e calorie = 0 , so we will show in catrgory wise for            Ex. In "Coffee & Tea" category
#  1)"Coffee (Small)"
#  2)"Iced Tea (Child)"
#  3)"Iced Tea (Large)"
#  4)"Iced Tea (Medium)"
#  5)"Iced Tea (Small)"
#  6)"Coffee (Large)"
#  7)"Coffee (Medium)"
#
#  In "Beverages"
#  1)"Dasani Water Bottle"
#  2)"Diet Dr Pepper (Medium)"
#  3)"Diet Dr Pepper (Child)"
#  4)"Diet Dr Pepper (Large)"
#  5)"Diet Dr Pepper (Small)"
#  6)"Diet Coke (Child)"
#  7)"Diet Coke (Large)"
#  8)"Diet Coke (Medium)"
#  9)"Diet Coke (Small)"
#
#  The above items having Minimum calorie counts i.e zero

# %%
# item having max. calorie
max_calories = item_calorie["Calories"].max()
max_item_cal = item_calorie[item_calorie["Calories"] == max_calories]
max_item_cal
# Out:
#           Category                          Item  Calories
# 82  Chicken & Fish  Chicken McNuggets (40 piece)      1880

# %% [markdown]
# ### conclusion:   From above we can conclude that the item which having Maximum calorie count is "Chicken                                       McNuggets (40 piece)"

# %% [markdown]
#  ### Question: Identify which menu item is healthy and less healthy based on the each nutritonal content.

# %% [markdown]
# ->1) To find out which menu item is healthy, we will filter out on the basis of min. and max. intake of each nutritional            content for average healthy person.
#
# ->2) we will first filtered out menu items on first nutritional content then we will take that dataframe further and filtered        out on the basis of 2nd nutritional content and similarly we will take that dataframe which is generated from 2nd              nutritional content  and filtered out on basis of 3rd nutritional content and this process we will continues till we will      filtered out on all nutritional content of our dataframe containing and finally we will conclude from this which food is        healthy.

# %% [markdown]
# ### 1) Saturated Fat (% Daily Value):
#
# #### Healthy: Low  saturated fat content is considerd to be healthy and So, if a food item has more than 10% Daily Value saturated fat,                        it’s considered high in fat.
# #### Less Healthy: High saturated fat content is considerd to be less healthy and it may cause risk for heart disease and stroke.

# %%
# Now we will filter out our dataframe on the basis of Saturated Fat (% Daily Value) which having less than 10% 
# and it is considered to be healthy with respect to saturated Fat (% Daily Value)

healthy_saturated_fat= data[(data["Saturated Fat (% Daily Value)"]  < 10)]
healthy_saturated_fat
# Out:
#                Category                                       Item  \
# 35            Breakfast                                   Hotcakes
# 38            Breakfast                                 Hash Brown
# 40            Breakfast                      Fruit & Maple Oatmeal
# 41            Breakfast  Fruit & Maple Oatmeal without Brown Sugar
# 58       Chicken & Fish   Premium Grilled Chicken Classic Sandwich
# ..                  ...                                        ...
# 236  Smoothies & Shakes        Strawberry Banana Smoothie (Medium)
# 237  Smoothies & Shakes         Strawberry Banana Smoothie (Large)
# 238  Smoothies & Shakes           Mango Pineapple Smoothie (Small)
# 239  Smoothies & Shakes          Mango Pineapple Smoothie (Medium)
# 240  Smoothies & Shakes           Mango Pineapple Smoothie (Large)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 35             151.000       350                 80        9.0
# ...

# %% [markdown]
# ### Result: Out of 260 items the above 74 items considered to be healthy and the rest are less healthy according to                     the "Saturated Fat (% Daily Value)".

# %%
# And further if we want to check how many items are present in category wise for above dataframe

healthy_saturated_fat.groupby("Category")["Category"].value_counts().sort_values(ascending=False)
# Out:
# Category
# Beverages             27
# Coffee & Tea          26
# Smoothies & Shakes     9
# Snacks & Sides         5
# Breakfast              4
# Chicken & Fish         1
# Desserts               1
# Salads                 1
# Name: count, dtype: int64

# %% [markdown]
# ### Result : From above, we can conclude that Beverages category has 27 items out of total 74 items in all category and followed by coffee and tea category which has 26 items.

# %% [markdown]
# ### Now we will filtered out further above dataframe on the basis of Cholesterol (% Daily Value).
#
# ### 2)Cholesterol (% Daily Value):
#
# #### Healthy: If menu items has Cholesterol (% Daily Value) less than 20% is considered to be healthy.
#
# #### Less Healthy: Cholesterol (% Daily Value) more than 20% is considered to be less healthy.

# %%
cholestrol=healthy_saturated_fat[["Item","Cholesterol (% Daily Value)"]].sort_values("Cholesterol (% Daily Value)",ascending=False)
cholestrol
# Out:
#                                                   Item  \
# 58            Premium Grilled Chicken Classic Sandwich
# 35                                            Hotcakes
# 87           Premium Southwest Salad (without Chicken)
# 177  Nonfat Latte with Sugar Free French Vanilla Sy...
# 165                               Nonfat Latte (Large)
# ..                                                 ...
# 141                                  Sweet Tea (Small)
# 142                                 Sweet Tea (Medium)
# 143                                  Sweet Tea (Large)
# 144                                  Sweet Tea (Child)
# 135                   Minute Maid Orange Juice (Large)
#
#      Cholesterol (% Daily Value)
# 58                            22
# 35                             7
# 87                             3
# 177                            3
# 165                            3
# ..                           ...
# 141                            0
# ...

# %% [markdown]
# ### Result: From above we can say that only one itemi.e Premium Grilled Chicken Classic Sandwich has                                       Cholesterol (% Daily Value) greater than 20%, so we will drop that row only and our data frame is got                         filtered out on the basis of Cholesterol (% Daily Value).

# %%
cholestrol_healthy =healthy_saturated_fat[(healthy_saturated_fat["Cholesterol (% Daily Value)"]  < 20)]
cholestrol_healthy
# Out:
#                Category                                       Item  \
# 35            Breakfast                                   Hotcakes
# 38            Breakfast                                 Hash Brown
# 40            Breakfast                      Fruit & Maple Oatmeal
# 41            Breakfast  Fruit & Maple Oatmeal without Brown Sugar
# 87               Salads  Premium Southwest Salad (without Chicken)
# ..                  ...                                        ...
# 236  Smoothies & Shakes        Strawberry Banana Smoothie (Medium)
# 237  Smoothies & Shakes         Strawberry Banana Smoothie (Large)
# 238  Smoothies & Shakes           Mango Pineapple Smoothie (Small)
# 239  Smoothies & Shakes          Mango Pineapple Smoothie (Medium)
# 240  Smoothies & Shakes           Mango Pineapple Smoothie (Large)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 35             151.000       350                 80        9.0
# ...

# %% [markdown]
# ### we will proceed further and filter out the remaining 73 items on the basis of Carbohydrates (% Daily Value).
#
# ### 3) Carbohydrates (% Daily Value) :
#
# ### Result: There is no specific % Daily Value for carbohydrates, but focus on quality sources.

# %% [markdown]
# ### we will proceed further and filter out the remaining 73 items on the basis of Dietary Fiber (% Daily Value)
#
# ### 4) Dietary Fiber (% Daily Value):
#
# #### Healthy: The minimum value is 9 % Daily Value  and below which is considered to be less healthy.

# %%
Dietary_Fiber_healthy =healthy_saturated_fat[(healthy_saturated_fat["Dietary Fiber (% Daily Value)"]  >= 9 )]
Dietary_Fiber_healthy
# Out:
#                Category                                       Item  \
# 35            Breakfast                                   Hotcakes
# 40            Breakfast                      Fruit & Maple Oatmeal
# 41            Breakfast  Fruit & Maple Oatmeal without Brown Sugar
# 58       Chicken & Fish   Premium Grilled Chicken Classic Sandwich
# 87               Salads  Premium Southwest Salad (without Chicken)
# 96       Snacks & Sides                         Small French Fries
# 232  Smoothies & Shakes     Blueberry Pomegranate Smoothie (Small)
# 233  Smoothies & Shakes    Blueberry Pomegranate Smoothie (Medium)
# 234  Smoothies & Shakes     Blueberry Pomegranate Smoothie (Large)
# 235  Smoothies & Shakes         Strawberry Banana Smoothie (Small)
# 236  Smoothies & Shakes        Strawberry Banana Smoothie (Medium)
# 237  Smoothies & Shakes         Strawberry Banana Smoothie (Large)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# ### Result: Out of 73 items the above 12 items considered to be healthy and the rest are less healthy according to                     the "Dietary Fiber (% Daily Value)"

# %% [markdown]
# ### we will proceed further and filter out the remaining 12 items on the basis of Iron (% Daily Value).
#
# ### 5) Iron (% Daily Value) :
#
# #### Healthy :If the food has more than 5% of the daily value then it is a good source of iron
#
# #### Less healthy : If the food has 5% or less than 5%  of the daily value then it is a poor source of iron

# %%
Iron_healthy=Dietary_Fiber_healthy[(Dietary_Fiber_healthy["Iron (% Daily Value)"]  > 5 )]
Iron_healthy
# Out:
#           Category                                       Item  \
# 35       Breakfast                                   Hotcakes
# 40       Breakfast                      Fruit & Maple Oatmeal
# 41       Breakfast  Fruit & Maple Oatmeal without Brown Sugar
# 58  Chicken & Fish   Premium Grilled Chicken Classic Sandwich
# 87          Salads  Premium Southwest Salad (without Chicken)
#
#     serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 35              151.0       350                 80        9.0
# 40              251.0       290                 35        4.0
# 41              251.0       260                 40        4.0
# 58              200.0       350                 80        9.0
# 87              230.0       140                 40        4.5
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 35                         13            2.0                              9
# ...

# %% [markdown]
# ### Result: Out of 12 items the above 5 items considered to be healthy and the rest are less healthy according to                     the "Iron (% Daily Value)"

# %% [markdown]
# ### we will proceed further and filter out the remaining 5 items on the basis of Vitamin C (% Daily Value).
#
# ### 6) Vitamin C (% Daily Value):
#
# #### Healthy: If the food has more than 7% of the daily value then it is a good source of Vitamin C.
#
# #### less healthy: If the food has less than 8% of the daily value then it is a poor source of Vitamin C

# %%
Vitamin_C_healthy=Iron_healthy[(Iron_healthy["Vitamin C (% Daily Value)"]  > 8 )]
Vitamin_C_healthy
# Out:
#      Category                                       Item  serving Size (gm)  \
# 40  Breakfast                      Fruit & Maple Oatmeal              251.0
# 41  Breakfast  Fruit & Maple Oatmeal without Brown Sugar              251.0
# 87     Salads  Premium Southwest Salad (without Chicken)              230.0
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 40       290                 35        4.0                          6
# 41       260                 40        4.0                          6
# 87       140                 40        4.5                          7
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 40            1.5                              8        0.0  ...
# 41            1.5                              8        0.0  ...
# 87            2.0                              9        0.0  ...
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# ...

# %% [markdown]
# ### Result: Out of 5 items the above 3 items considered to be healthy and the rest are less healthy according to                     the "Vitamin C (% Daily Value)"

# %% [markdown]
# ### we will proceed further and filter out the remaining 3 items on the basis of Vitamin A (% Daily Value).
#
# ### 7) Vitamin A (% Daily Value):
#
# #### Healthy: If the food has greater than equal to 10% of the daily value then it is a good source of Vitamin A.

# %%
Vitamin_A_healthy=Vitamin_C_healthy[(Vitamin_C_healthy["Vitamin A (% Daily Value)"]  >= 10 )]
Vitamin_A_healthy
# Out:
#    Category                                       Item  serving Size (gm)  \
# 87   Salads  Premium Southwest Salad (without Chicken)              230.0
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 87       140                 40        4.5                          7
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 87            2.0                              9        0.0  ...
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 87                             23       6        6                        160
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 87                         25                       15                    10
#
#     Calories (% Daily Value)  Sugars (% Daily Value)  Protein (% Daily Value)
# 87                       5.6                    20.0                     12.0
#
# [1 rows x 27 columns]

# %% [markdown]
# ###  Result: Only one item is remaining out of 3 items and rest are less healthy according to the                                                      "Iron (% Daily Value)"

# %% [markdown]
# ### we will check last nutritional content to the above menu item.
#
# ### 8) Calcium (% Daily Value) :
#
# #### Healthy:: If the food has greater than equal to 10% of the daily value then it is a good source of calcium.

# %%
Calcium_healthy=Vitamin_A_healthy[(Vitamin_A_healthy["Calcium (% Daily Value)"]  >= 10 )]
Calcium_healthy
# Out:
#    Category                                       Item  serving Size (gm)  \
# 87   Salads  Premium Southwest Salad (without Chicken)              230.0
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 87       140                 40        4.5                          7
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 87            2.0                              9        0.0  ...
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 87                             23       6        6                        160
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 87                         25                       15                    10
#
#     Calories (% Daily Value)  Sugars (% Daily Value)  Protein (% Daily Value)
# 87                       5.6                    20.0                     12.0
#
# [1 rows x 27 columns]

# %% [markdown]
# ### CONCLUSION: By filtering out from all nutrional content the "PREMIUM SOUTHWEST SALAD                                                                (WITHOUT CHICKEN)" is the " HEALTHIEST " food item among 260 items and it comes from                                         "SALAD" category.

# %% [markdown]
# ### Question: Now we will find out the less healthy menu item from our dataset.
#
# ### Ans: The main filtering column will be Saturated Fat (% Daily Value) and Cholesterol (% Daily Value) because it                  causes the heart related diseases i.e Heart attack

# %%
# 1)Saturated Fat (% Daily Value) 

less_healthy_saturated_fat = max(data['Saturated Fat (% Daily Value)'])
data[data['Saturated Fat (% Daily Value)'] == less_healthy_saturated_fat]
# Out:
#                Category                                  Item  \
# 253  Smoothies & Shakes  McFlurry with M&M’s Candies (Medium)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 253              460.0       930                290       33.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 253                         50           20.0                            102
#
#      Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 253        1.0  ...                              7     128       20
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 253                         25                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Calories (% Daily Value)  \
# 253                       70                    10                      37.2
#
#      Sugars (% Daily Value)  Protein (% Daily Value)
# 253                  426.67                     40.0
#
# [1 rows x 27 columns]

# %% [markdown]
# ### CONCLUSION: "McFlurry with M&M’s Candies (Medium)" has the highest Saturated Fat (% Daily Value) out of                                      260 items which is 102 and it will be "LESS HEALTHY" menu item on the basis of Saturated                                          Fat (%Daily Value).

# %%
# Cholesterol (% Daily Value)
less_healthy_Cholesterol= max(data['Cholesterol'])
data[(data.Cholesterol ==less_healthy_Cholesterol)]
# Out:
#      Category                                           Item  \
# 31  Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
# 32  Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
#
#     serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 31              420.0      1090                510       56.0
# 32              434.0      1150                540       60.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 31                         87           19.0                             96
# 32                         93           20.0                            100
#
#     Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 31        0.0  ...                             23      17       36
# 32        0.0  ...                             28      17       36
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 31                         15                          2
# ...

# %% [markdown]
# ### CONCLUSION: "Big Breakfast with Hotcakes (Regular Biscuit)" and "Big Breakfast with Hotcakes (Large                                              Biscuit)" has the highest cholestrol value out of 260 items which is 575 and it will be                                                      "LESS HEALTHY" menu item on the basis of cholestrol.

# %% [markdown]
# ## Question:Now we will check which nutrient contents have an outlier?
#
# ### Note: I am using the subplot of three, so it is easy from appearance perpestive.

# %%
#Checking for the outliers - first set
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= data['Calories'], color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x= data['Calories from Fat'], color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x= data['Total Fat'], color='lightblue')


plt.show()

# %%
#Checking for the outliers - second set
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= data['Saturated Fat'], color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x= data['Cholesterol'], color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x= data['Trans Fat'], color='lightblue')


plt.show()

# %%
#Checking for the outliers - third set
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= data['Sodium'], color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x= data['Dietary Fiber'], color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x= data['Sugars'], color='lightblue')


plt.show()

# %%
#Checking for the outliers - fourth set
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= data['Protein'], color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x= data['Vitamin A (% Daily Value)'], color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x= data['Vitamin C (% Daily Value)'], color='lightblue')


plt.show()

# %%
#Checking for the outliers - fifth set
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= data['Calcium (% Daily Value)'], color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x= data['Iron (% Daily Value)'], color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x= data['Carbohydrates'], color='lightblue')


plt.show()

# %%
#Checking for the outliers - sixth set
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= data['Total Fat (% Daily Value)'], color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x= data['Saturated Fat (% Daily Value)'], color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x= data['Cholesterol (% Daily Value)'], color='lightblue')


plt.show()

# %%
#Checking for the outliers - seventh set
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= data['Sodium (% Daily Value)'], color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x= data['Carbohydrates (% Daily Value)'], color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x=data['Dietary Fiber (% Daily Value)'], color='lightblue')


plt.show()

# %% [markdown]
# Observation :
# Based on the above  visualization, the below variables have outlier:
#
# Calories                           outlier
# Calories from Fat                  outlier
# Total Fat                          outlier
# Total Fat (% Daily Value)          outlier
# Trans Fat                          outlier
# Cholesterol                        outlier
# Cholesterol (% Daily Value)        outlier
# Sodium                             outlier
# Sodium (% Daily Value)             outlier
# Carbohydrates                      outlier
# Carbohydrates (% Daily Value)      outlier
# Dietary Fiber (% Daily Value)      outlier
# Sugars                             outlier
# Protein                            outlier
# Vitamin A (% Daily Value)          outlier
# Vitamin C (% Daily Value)          outlier
# Calcium (% Daily Value)            outlier
# Iron (% Daily Value)               outlier
#
# ------
# Saturated Fat                      No outlier
# Dietary Fiber                      No outlier
# Saturated Fat (% Daily Value)      No outlier

# %% [markdown]
# ### Question : Identify which category and menu item has the highest nutrient content :
#
# ### Solution: we will find out first category wise that which category has the highest nutrient content then we will                           find out menu wise for each nutrient content.

# %%
# 1)Vitamin A (% Daily Value)
data.pivot_table('Vitamin A (% Daily Value)', 'Category').plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### Conclusion :
#
# From the above bar graph, we can conclude that "SALADS" has the highest "Vitamin A (% Daily Value)" among all the category.

# %%
max_Vitamin_A_item = max(data['Vitamin A (% Daily Value)'])
data[data['Vitamin A (% Daily Value)'] == max_Vitamin_A_item ]
# Out:
#    Category                                          Item  serving Size (gm)  \
# 84   Salads   Premium Bacon Ranch Salad (without Chicken)              223.0
# 88   Salads   Premium Southwest Salad with Crispy Chicken              348.0
# 89   Salads  Premium Southwest Salad with Grilled Chicken              335.0
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 84       140                 70        7.0                         11
# 88       450                190       22.0                         33
# 89       290                 80        8.0                         13
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 84            3.5                             18        0.0  ...
# 88            4.5                             22        0.0  ...
# 89            2.5                             13        0.0  ...
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# ...

# %% [markdown]
# ### conclusion:
#
# ->  "Premium Bacon Ranch Salad (without Chicken)", "Premium Southwest Salad with Crispy Chicken" and "Premium Southwest Salad        with Grilled Chicken" has the highest "Vitamin A (% Daily Value)" out of 260 items and it comes under "salads" category.

# %%
# 2)Vitamin C (% Daily Value)

data.pivot_table('Vitamin C (% Daily Value)', 'Category').plot(kind='bar', stacked=True, color = 'c')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# -> From the above bar graph, we are not able to conclude that "Salad" or "snacks & sides" has the highest Average                  "Vitamin C(% Daily Value)" , so we will find out their numeerical value.

# %%
data.groupby("Category")["Vitamin C (% Daily Value)"].mean()
# Out:
# Category
# Beef & Pork            7.333333
# Beverages             23.481481
# Breakfast              8.904762
# Chicken & Fish        12.629630
# Coffee & Tea           0.000000
# Desserts               4.142857
# Salads                28.333333
# Smoothies & Shakes     6.964286
# Snacks & Sides        28.153846
# Name: Vitamin C (% Daily Value), dtype: float64

# %% [markdown]
# ### conclusion:
#
# From the above bar graph, we can conclude that "Salad" has the highest Average "Vitamin C (% Daily Value)" which is 28.33 among all the category.

# %%
max_Vitamin_C_item= max(data['Vitamin C (% Daily Value)'])
data[data['Vitamin C (% Daily Value)'] == max_Vitamin_C_item]
# Out:
#       Category                              Item  serving Size (gm)  Calories  \
# 135  Beverages  Minute Maid Orange Juice (Large)            650.617       280
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 135                  0        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 135                              0        0.0  ...
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 135                              0      58        4
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 135                          0                        240
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Calories (% Daily Value)  \
# 135                        4                     0                      11.2
#
#      Sugars (% Daily Value)  Protein (% Daily Value)
# 135                  193.33                      8.0
#
# [1 rows x 27 columns]

# %% [markdown]
# ### conclusion:
#
# ->  "Minute Maid Orange Juice (Large)" has highest "Vitamin C (% Daily Value)" out of 260 items and it comes under "Beverages"     category.

# %%
# 3) "Calcium (% Daily Value)"

data.pivot_table('Calcium (% Daily Value)', 'Category').plot(kind='bar', stacked=True, color = 'c')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# ->From the above bar graph, we can conclude that "Smoothies and shakes" has the highest "Calcium(% Daily Value)" among all the   category.

# %%
max_calcium_item = max(data['Calcium (% Daily Value)'])
data[data['Calcium (% Daily Value)'] == max_calcium_item]
# Out:
#                Category                                  Item  \
# 246  Smoothies & Shakes              Strawberry Shake (Large)
# 253  Smoothies & Shakes  McFlurry with M&M’s Candies (Medium)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 246            650.617       850                210       24.0
# 253            460.000       930                290       33.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 246                         36           15.0                             75
# 253                         50           20.0                            102
#
#      Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 246        1.0  ...                              0     123       18
# 253        1.0  ...                              7     128       20
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 246                         30                          0
# ...

# %% [markdown]
# ### conclusion:
#
# -> "Strawberry Shake (Large)" and "McFlurry with M&M’s Candies (Medium)" has the highest "Calcium(% Daily Value)" out of 260      items and it comes under "Smoothies & Shakes" category.

# %%
# 4)'Iron (% Daily Value)'

data.pivot_table('Iron (% Daily Value)', 'Category').plot(kind='bar', stacked=True, color = 'k')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# -> From the above bar graph, we can conclude that "Beef and pork" has the highest 'Iron (% Daily Value)' among all the            category.

# %%
max_Iron_item= max(data['Iron (% Daily Value)'])
data[data['Iron (% Daily Value)'] == max_Iron_item]
# Out:
#      Category                                           Item  \
# 31  Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
# 32  Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
#
#     serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 31              420.0      1090                510       56.0
# 32              434.0      1150                540       60.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 31                         87           19.0                             96
# 32                         93           20.0                            100
#
#     Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 31        0.0  ...                             23      17       36
# 32        0.0  ...                             28      17       36
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 31                         15                          2
# ...

# %% [markdown]
# ### conclusion :
#
# -> "Big Breakfast with Hotcakes (Regular Biscuit)" and "Big Breakfast with Hotcakes (Large Biscuit)" has highest "Iron (% Daily     Value)" out of 260 items and it comes under "Breakfast" category.

# %%
# 5) "Cholestrol"

data.pivot_table('Cholesterol', 'Category').plot(kind='bar', stacked=True, color = 'r')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# ->From the above bar graph, we can conclude that "Breakfast" has the highest "Cholestrol" among all the category.

# %%
max_cholestrol_item = max(data['Cholesterol'])
data[(data.Cholesterol == max_cholestrol_item)]
# Out:
#      Category                                           Item  \
# 31  Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
# 32  Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
#
#     serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 31              420.0      1090                510       56.0
# 32              434.0      1150                540       60.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 31                         87           19.0                             96
# 32                         93           20.0                            100
#
#     Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 31        0.0  ...                             23      17       36
# 32        0.0  ...                             28      17       36
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 31                         15                          2
# ...

# %% [markdown]
# ### conclusion:
#
# -> "Big Breakfast with Hotcakes (Regular Biscuit)" and "Big Breakfast with Hotcakes (Large Biscuit)" has the highest              "Cholestrol" value and it is very dangerous to our heart beacuse it will cause heart attack.
#
# -> Probably better to have Breakfast at home.

# %%
# 6) "Protein"

data.pivot_table('Protein', 'Category').plot(kind='bar', stacked=True, color = 'b')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# -> From the above bar graph, we can conclude that "chicken and fish" has the highest 'Protein' among all the category.

# %%
max_protein_item= max(data['Protein'])
data[data.Protein == max_protein_item]
# Out:
#           Category                          Item  serving Size (gm)  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)              646.0      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 82                            101        1.0  ...
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 82                         15                        8                    25
#
#     Calories (% Daily Value)  Sugars (% Daily Value)  Protein (% Daily Value)
# 82                      75.2                    3.33                    174.0
#
# [1 rows x 27 columns]

# %% [markdown]
# ### conclusion :
#
# -> "Chicken McNuggets (40 piece)" has highest "Protein" out of 260 items and it comes under "hicken & Fish" category.

# %%
# 7) Dietary Fiber (% Daily Value)

data.pivot_table('Dietary Fiber (% Daily Value)', 'Category').plot(kind='bar', stacked=True, color = 'c')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# -> From the above bar graph, we can conclude that "salads" has the highest 'Dietary Fiber(% Daily Value)'  among all the category.

# %%
max_dietary_fibre_item = max(data['Dietary Fiber (% Daily Value)'])
data[data['Dietary Fiber (% Daily Value)'] == max_dietary_fibre_item ]
# Out:
#      Category                                               Item  \
# 32  Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 34  Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 88     Salads        Premium Southwest Salad with Crispy Chicken
# 89     Salads       Premium Southwest Salad with Grilled Chicken
#
#     serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 32              434.0      1150                540       60.0
# 34              437.0      1050                450       50.0
# 88              348.0       450                190       22.0
# 89              335.0       290                 80        8.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 32                         93           20.0                            100
# 34                         77           16.0                             81
# 88                         33            4.5                             22
# ...

# %% [markdown]
# ### conclusion :
#
# -> "Big Breakfast with Hotcakes (Large Biscuit)","Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)" comes                 under "Breakfast" category and "Premium Southwest Salad with Crispy Chicken" and "Premium Southwest Salad with Grilled         Chicken" comes under "Salads" category which has highest "Protein" out of 260 items.

# %%
# 8) Carbohydrates (% Daily Value)

data.pivot_table('Carbohydrates (% Daily Value)', 'Category').plot(kind='bar', stacked=True, color = 'y')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# ->  From the above bar graph, we can conclude that "Smoothies & shakes" has the highest 'Carbohydrates (% Daily Value)' among       all the category.

# %%
max_carbohydrate_item = max(data['Carbohydrates (% Daily Value)'])
data[data['Carbohydrates (% Daily Value)'] == max_carbohydrate_item]
# Out:
#                Category                      Item  serving Size (gm)  \
# 246  Smoothies & Shakes  Strawberry Shake (Large)            650.617
# 249  Smoothies & Shakes   Chocolate Shake (Large)            650.617
#
#      Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 246       850                210       24.0                         36
# 249       850                210       23.0                         36
#
#      Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 246           15.0                             75        1.0  ...
# 249           15.0                             74        1.0  ...
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 246                              0     123       18
# 249                              8     120       19
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 246                         30                          0
# ...

# %% [markdown]
# ### conclusion:
#
# -> "Strawberry Shake (Large)" and "Chocolate Shake (Large)" has highest "Carbohydrates (% Daily Value)" out of 260 items.

# %%
# 9) Sodium (% Daily Value)

data.pivot_table('Sodium (% Daily Value)', 'Category').plot(kind='bar', stacked=True, color = 'c')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# ->  From the above bar graph, we can conclude that "chicken & fish" has the highest 'Sodium (% Daily Value)' among all the         category.

# %%
max_sodium_item= max(data['Sodium (% Daily Value)'])
data[data['Sodium (% Daily Value)'] == max_sodium_item]
# Out:
#           Category                          Item  serving Size (gm)  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)              646.0      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 82                            101        1.0  ...
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 82                         15                        8                    25
#
#     Calories (% Daily Value)  Sugars (% Daily Value)  Protein (% Daily Value)
# 82                      75.2                    3.33                    174.0
#
# [1 rows x 27 columns]

# %% [markdown]
# ### conclusion:
#
# -> "Chicken McNuggets (40 piece)" has "Sodium (% Daily Value)" of 150 which is highest out of 260 items and its dangerous
#     because it may cause blood pressure problems.

# %%
#10) Saturated Fat (% Daily Value)

data.pivot_table('Saturated Fat (% Daily Value)', 'Category').plot(kind='bar', stacked=True, color = 'r')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### conclusion:
#
# -> From the above bar graph, we can conclude that "Breakfast" has the highest "Saturated Fat (% Daily Value)" among
#    all the category.

# %%
max_saturated_fat_item = max(data['Saturated Fat (% Daily Value)'])
data[data['Saturated Fat (% Daily Value)'] == max_saturated_fat_item]
# Out:
#                Category                                  Item  \
# 253  Smoothies & Shakes  McFlurry with M&M’s Candies (Medium)
#
#      serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 253              460.0       930                290       33.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 253                         50           20.0                            102
#
#      Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 253        1.0  ...                              7     128       20
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 253                         25                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Calories (% Daily Value)  \
# 253                       70                    10                      37.2
#
#      Sugars (% Daily Value)  Protein (% Daily Value)
# 253                  426.67                     40.0
#
# [1 rows x 27 columns]

# %% [markdown]
# ## conclusion:
#
# ###  "McFlurry with M&M’s Candies (Medium)" has "Saturated Fat (% Daily Value)" of 102 which is highest out of 260 items and its    dangerous because it may cause heart related problems.

# %% [markdown]
# ### Question: Compare nutritional characteristic of different food categories.
#
# ### Ans: i am comparing nutritional characteristic of  "Salads" and "Desserts" category

# %%
Desserts = data[data['Category'].str.contains('Desserts')]
salads = data[data['Category'].str.contains('Salad')]

# Calculate summary statistics
Desserts_stats = Desserts.describe().loc[['mean', 'std', 'min', 'max']].transpose().round(2)
salads_stats = salads.describe().loc[['mean', 'std', 'min', 'max']].transpose().round(2)

# Print or display the results
print("Statistics for Desserts:")
print(Desserts_stats)
print("\nStatistics for Salads:")
print(salads_stats)
# Out:
# Statistics for Desserts:
#                                  mean     std   min    max
# serving Size (gm)              101.57   74.81  29.0  182.0
# Calories                       222.14  108.08  45.0  340.0
# Calories from Fat               64.29   30.47  10.0  110.0
# Total Fat                        7.36    3.50   1.5   13.0
# Total Fat (% Daily Value)       11.14    5.18   2.0   19.0
# Saturated Fat                    4.29    2.23   1.0    7.0
# Saturated Fat (% Daily Value)   21.29   11.04   4.0   35.0
# Trans Fat                        0.00    0.00   0.0    0.0
# Cholesterol                     15.00   11.55   0.0   30.0
# Cholesterol (% Daily Value)      4.86    3.76   0.0   10.0
# Sodium                         117.14   55.06  20.0  170.0
# Sodium (% Daily Value)           5.00    2.16   1.0    7.0
# Carbohydrates                   34.86   19.59   7.0   60.0
# Carbohydrates (% Daily Value)   11.57    6.65   2.0   20.0
# ...

# %% [markdown]
# ### Conclusion: From above dataframe we can easily compare the values of each nutritional content.                                                   for e.g Mean calorie of salads is greater than desserts.  similarly we can compare any nutritional                                 content of above two category.

# %% [markdown]
# ### QUESTION: Now we will compare nutritional content between "crispy" and "grilled" sandwich.

# %%
crispy_vs_no = data[data['Item'].str.contains('Sandwich')].reset_index(drop=True)

crispy = crispy_vs_no[crispy_vs_no['Item'].str.contains('Crispy')].reset_index(drop=True)
grilled = crispy_vs_no[crispy_vs_no['Item'].str.contains('Grilled')].reset_index(drop=True)

label = grilled[grilled['Item'].str.contains('Grilled')]['Item'].replace('Grilled','',regex = True).tolist()

crispy.drop(['Category','Item','serving Size (gm)'], axis=1,inplace = True)
grilled.drop(['Category','Item','serving Size (gm)'], axis=1,inplace = True)

crispy_vs_no.head(2)
# Out:
#          Category                                      Item  \
# 0  Chicken & Fish   Premium Crispy Chicken Classic Sandwich
# 1  Chicken & Fish  Premium Grilled Chicken Classic Sandwich
#
#    serving Size (gm)  Calories  Calories from Fat  Total Fat  \
# 0              213.0       510                200       22.0
# 1              200.0       350                 80        9.0
#
#    Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                         33            3.5                             18
# 1                         13            2.0                              9
#
#    Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0        0.0  ...                             13      10       24
# 1        0.0  ...                             13       8       28
#
#    Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                          4                          6
# ...

# %%
def comparison_plot(dataframe, plot_title, row, column, last_blank=False):
    label = ['Calories (% Daily Value)', 'Total Fat (% Daily Value)', 'Saturated Fat (% Daily Value)',
             'Cholesterol (% Daily Value)', 'Sodium (% Daily Value)', 'Carbohydrates (% Daily Value)',
             'Dietary Fiber (% Daily Value)', 'Sugars (% Daily Value)', 'Protein (% Daily Value)',
             'Dietary Fiber (% Daily Value)', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
             'Calcium (% Daily Value)']

    label_tick = ['Calories', 'Total Fat', 'Saturated Fat', 'Cholesterol', 'Sodium', 'Carbohydrates',
                  'Dietary Fiber', 'Sugar', 'Protein', 'Dietary Fiber', 'Vitamin A', 'Vitamin C', 'Calcium']

    n = len(label)
    ind = np.arange(n)

    width = 0.3
    fig, axs = plt.subplots(row, column)
    if last_blank:
        axs[-1, -1].axis('off')

    fig.set_figheight(10)
    fig.set_figwidth(20)

    index = 0
    for ax in axs:
        for x in ax:
            if last_blank and index == (row * column * 2) - 2:
                continue
            x.bar(ind - width/2, dataframe.iloc[index][label].tolist(), width, label=dataframe.iloc[index]['Item'])
            x.bar(ind + width/2, dataframe.iloc[index+1][label].tolist(), width, label=dataframe.iloc[index+1]['Item'])
            if index == 4 or index == 6:
                x.set_xticks(ind)
                x.set_xticklabels(label_tick)
                x.tick_params(labelrotation=90)
            else:
                x.set_xticks(ind)
                x.set_xticklabels([""]*len(label_tick))
            x.legend()
            index +=2
    fig.suptitle(plot_title,fontsize = 20)
comparison_plot(crispy_vs_no,'Crispy vs Grilled Sandwich Comparison',2,2)

# Assuming crispy_vs_no is your DataFrame
# comparison_plot(crispy_vs_no, 'Crispy vs Grilled Sandwich Comparison', 2, 2)

# %% [markdown]
# ### CONCLUSION: From the figure, mostly crispy sandwich has more nutrient rather than grilled. But in grilled                                         sandwich have more cholesterol, protein and vitamin c rather than in crispy sandwich.

# %% [markdown]
# ## IMPORTANT INSIGHTS :
#
# ### 1)	"Coffee & Tea" category has maximum number of items which is 36.5% of total no. of items and that much number of items of particular one category should not be their and it should be reduced.
#
# ### 2)	 There are about 16 items which having Zero calories and just because a food is lower in calories doesn't mean it makes a better choice than higher calorie foods. Your body needs adequate calories on a daily basis to function optimally and help you feel your best. It's not a good idea to choose foods based simply on their calorie content.
#
# ### 3)	The "PREMIUM SOUTHWEST SALAD (WITHOUT CHICKEN)" is the "HEALTHIEST" food item among 260 items and it comes from "SALAD" category and salad category has only 6 items and it should be increased because it is a healthy diet.
#
# ### 4)	"Big Breakfast with Hotcakes (Regular Biscuit)" and "Big Breakfast with Hotcakes (Large Biscuit)" has the highest cholestrol value and "McFlurry with M&M’s Candies (Medium)" has the highest Saturated Fat (% Daily Value) out of 260 items and this items are "LESS HEALTHY"  and it should be removed from menu items list because it may cause heart related problems i.e Heart attack.
